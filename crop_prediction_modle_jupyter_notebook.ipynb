# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Crop_recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
X
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
Y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y , test_size=0.3,random_state=50)

# %%
X_train
# Out:
#         N    P    K  temperature   humidity        ph    rainfall
# 243    57   68   81    17.170126  17.304577  8.081095   72.786242
# 23     83   41   43    21.052536  82.678395  6.254028  233.107582
# 782    41   74   18    28.757518  61.027015  6.599147   73.376868
# 1571    5  136  195    22.356287  91.923605  6.264203  107.769741
# 1430  100   17   48    29.727911  94.297533  6.367801   26.523641
# ...   ...  ...  ...          ...        ...       ...         ...
# 2014   67   43   38    25.216227  70.882596  7.299305  195.864555
# 2157  115   31   30    24.229847  67.377684  6.840928  122.407342
# 1931  107   51   22    24.865608  78.220808  5.983076   79.568663
# 1504   20  129  201    23.410447  91.699133  5.587906  116.077793
# 1712   44   64   54    29.807443  91.380485  6.742749  232.704613
#
# [1540 rows x 7 columns]

# %%
X_test
# Out:
#        N    P    K  temperature   humidity        ph    rainfall
# 349    9   80   19    21.806196  18.570866  5.945466  125.097269
# 1546  31  130  198    21.801298  92.734467  5.554824  120.058667
# 1746  35   66   47    31.701837  91.662322  6.953439   48.838106
# 1640   1   30   10    11.899257  91.346638  7.291406  103.577147
# 772   21   80   20    28.206673  68.270852  7.350870   64.328871
# ...   ..  ...  ...          ...        ...       ...         ...
# 19    88   35   40    23.579436  83.587603  5.853932  291.298662
# 1867   3   23   30    29.701432  95.657544  6.078807  215.196804
# 2027  76   44   45    25.487968  84.482359  6.740948  168.784889
# 2030  69   57   35    24.307486  78.543410  6.186814  186.233757
# 845   24   61   17    22.637142  65.445449  6.233269   38.304111
#
# [660 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=model.predict(X_test)

# %%
prediction
# Out:
# array(['kidneybeans', 'apple', 'papaya', 'orange', 'blackgram', 'coconut',
#        'pomegranate', 'lentil', 'watermelon', 'coconut', 'jute', 'grapes',
#        'chickpea', 'grapes', 'papaya', 'papaya', 'papaya', 'coffee',
#        'blackgram', 'coffee', 'watermelon', 'rice', 'maize', 'apple',
#        'lentil', 'apple', 'cotton', 'kidneybeans', 'muskmelon', 'grapes',
#        'watermelon', 'pigeonpeas', 'watermelon', 'papaya', 'coconut',
#        'coconut', 'watermelon', 'lentil', 'mungbean', 'blackgram',
#        'watermelon', 'jute', 'pigeonpeas', 'cotton', 'jute', 'coffee',
#        'kidneybeans', 'mothbeans', 'grapes', 'blackgram', 'coconut',
#        'jute', 'blackgram', 'mothbeans', 'watermelon', 'coconut',
#        'muskmelon', 'jute', 'maize', 'pigeonpeas', 'kidneybeans',
#        'coffee', 'pigeonpeas', 'blackgram', 'lentil', 'blackgram',
#        'watermelon', 'mothbeans', 'apple', 'papaya', 'pigeonpeas',
#        'orange', 'jute', 'orange', 'cotton', 'chickpea', 'mungbean',
#        'jute', 'kidneybeans', 'lentil', 'coconut', 'chickpea', 'rice',
#        'pigeonpeas', 'mothbeans', 'grapes', 'mothbeans', 'mango',
#        'pomegranate', 'mothbeans', 'grapes', 'papaya', 'apple', 'cotton',
#        'apple', 'kidneybeans', 'rice', 'muskmelon', 'rice', 'banana',
#        'maize', 'grapes', 'pomegranate', 'maize', 'cotton', 'mungbean',
#        'apple', 'lentil', 'blackgram', 'muskmelon', 'orange', 'coffee',
#        'pigeonpeas', 'papaya', 'coffee', 'coffee', 'cotton', 'mango',
#        'rice', 'chickpea', 'banana', 'maize', 'rice', 'coffee',
#        'pigeonpeas', 'watermelon', 'rice', 'chickpea', 'jute', 'mungbean',
#        'papaya', 'papaya', 'maize', 'cotton', 'kidneybeans', 'chickpea',
#        'pomegranate', 'maize', 'pomegranate', 'pomegranate', 'rice',
#        'coconut', 'watermelon', 'mothbeans', 'orange', 'pigeonpeas',
#        'grapes', 'apple', 'grapes', 'cotton', 'rice', 'cotton', 'lentil',
#        'mothbeans', 'jute', 'apple', 'maize', 'jute', 'mungbean', 'jute',
#        'mothbeans', 'coconut', 'kidneybeans', 'papaya', 'pomegranate',
#        'chickpea', 'jute', 'papaya', 'mango', 'coffee', 'banana',
#        'mothbeans', 'apple', 'maize', 'watermelon', 'coconut', 'jute',
#        'grapes', 'pigeonpeas', 'kidneybeans', 'banana', 'cotton',
#        'blackgram', 'coconut', 'coffee', 'chickpea', 'jute', 'jute',
#        'rice', 'chickpea', 'lentil', 'banana', 'coffee', 'mothbeans',
#        'grapes', 'rice', 'pigeonpeas', 'watermelon', 'grapes', 'chickpea',
#        'jute', 'banana', 'mango', 'rice', 'orange', 'coffee',
#        'pigeonpeas', 'muskmelon', 'papaya', 'coffee', 'cotton',
#        'watermelon', 'mothbeans', 'mothbeans', 'jute', 'chickpea',
#        'muskmelon', 'banana', 'mango', 'lentil', 'papaya', 'mango',
#        'mango', 'jute', 'coconut', 'chickpea', 'mungbean', 'pigeonpeas',
#        'lentil', 'chickpea', 'mango', 'muskmelon', 'apple', 'apple',
#        'papaya', 'chickpea', 'pigeonpeas', 'orange', 'coffee', 'papaya',
#        'papaya', 'pigeonpeas', 'kidneybeans', 'muskmelon', 'chickpea',
#        'coconut', 'pigeonpeas', 'orange', 'jute', 'apple', 'mothbeans',
#        'jute', 'pigeonpeas', 'mungbean', 'mothbeans', 'muskmelon',
#        'mango', 'papaya', 'apple', 'mango', 'pomegranate', 'lentil',
#        'coffee', 'maize', 'grapes', 'kidneybeans', 'jute', 'rice',
#        'coffee', 'cotton', 'chickpea', 'kidneybeans', 'chickpea',
#        'cotton', 'pigeonpeas', 'mungbean', 'maize', 'chickpea',
#        'chickpea', 'watermelon', 'mango', 'chickpea', 'coconut', 'coffee',
#        'mothbeans', 'mango', 'apple', 'mothbeans', 'coconut', 'rice',
#        'mango', 'pigeonpeas', 'blackgram', 'papaya', 'maize', 'rice',
#        'chickpea', 'coffee', 'pomegranate', 'maize', 'lentil', 'apple',
#        'watermelon', 'coconut', 'pigeonpeas', 'cotton', 'jute', 'jute',
#        'rice', 'mungbean', 'mango', 'cotton', 'blackgram', 'grapes',
#        'grapes', 'jute', 'pomegranate', 'lentil', 'rice', 'jute',
#        'blackgram', 'rice', 'papaya', 'mango', 'coconut', 'mothbeans',
#        'mungbean', 'apple', 'rice', 'blackgram', 'maize', 'maize',
#        'pomegranate', 'mungbean', 'pigeonpeas', 'mothbeans', 'chickpea',
#        'banana', 'jute', 'orange', 'blackgram', 'watermelon', 'grapes',
#        'cotton', 'lentil', 'mango', 'kidneybeans', 'orange', 'mango',
#        'cotton', 'blackgram', 'banana', 'pigeonpeas', 'jute', 'lentil',
#        'pomegranate', 'coconut', 'apple', 'mothbeans', 'coffee',
#        'coconut', 'grapes', 'rice', 'rice', 'blackgram', 'mothbeans',
#        'orange', 'mothbeans', 'jute', 'chickpea', 'mungbean', 'jute',
#        'banana', 'coconut', 'mango', 'cotton', 'grapes', 'grapes',
#        'coconut', 'papaya', 'grapes', 'mungbean', 'banana', 'blackgram',
#        'banana', 'pomegranate', 'mothbeans', 'kidneybeans', 'cotton',
#        'orange', 'coffee', 'jute', 'mothbeans', 'coconut', 'mango',
#        'lentil', 'orange', 'grapes', 'blackgram', 'apple', 'orange',
#        'grapes', 'maize', 'grapes', 'orange', 'grapes', 'lentil',
#        'banana', 'orange', 'rice', 'banana', 'pomegranate', 'mungbean',
#        'muskmelon', 'orange', 'pomegranate', 'apple', 'rice', 'lentil',
#        'lentil', 'orange', 'jute', 'watermelon', 'mungbean', 'mango',
#        'blackgram', 'muskmelon', 'muskmelon', 'papaya', 'grapes',
#        'lentil', 'blackgram', 'apple', 'mango', 'blackgram', 'apple',
#        'muskmelon', 'papaya', 'cotton', 'blackgram', 'pomegranate',
#        'papaya', 'kidneybeans', 'orange', 'grapes', 'mothbeans',
#        'muskmelon', 'orange', 'mungbean', 'mango', 'jute', 'maize',
#        'lentil', 'papaya', 'coffee', 'watermelon', 'pomegranate',
#        'banana', 'lentil', 'mungbean', 'mango', 'orange', 'orange',
#        'jute', 'lentil', 'watermelon', 'muskmelon', 'grapes', 'papaya',
#        'rice', 'coconut', 'kidneybeans', 'muskmelon', 'mothbeans',
#        'cotton', 'chickpea', 'kidneybeans', 'papaya', 'lentil', 'apple',
#        'watermelon', 'chickpea', 'coffee', 'maize', 'mothbeans',
#        'pomegranate', 'grapes', 'chickpea', 'cotton', 'chickpea',
#        'watermelon', 'orange', 'orange', 'coconut', 'muskmelon', 'rice',
#        'watermelon', 'mungbean', 'jute', 'pomegranate', 'mothbeans',
#        'papaya', 'maize', 'coconut', 'lentil', 'jute', 'cotton', 'apple',
#        'papaya', 'lentil', 'maize', 'muskmelon', 'coffee', 'orange',
#        'pigeonpeas', 'chickpea', 'jute', 'mungbean', 'pigeonpeas', 'rice',
#        'orange', 'coconut', 'lentil', 'apple', 'grapes', 'jute', 'orange',
#        'coconut', 'rice', 'watermelon', 'kidneybeans', 'apple', 'banana',
#        'orange', 'orange', 'grapes', 'mungbean', 'pomegranate',
#        'chickpea', 'papaya', 'jute', 'kidneybeans', 'cotton',
#        'pigeonpeas', 'papaya', 'mothbeans', 'cotton', 'coconut', 'rice',
#        'chickpea', 'pomegranate', 'mothbeans', 'coconut', 'lentil',
#        'mothbeans', 'banana', 'coconut', 'apple', 'coconut', 'papaya',
#        'rice', 'blackgram', 'blackgram', 'orange', 'kidneybeans',
#        'grapes', 'banana', 'blackgram', 'coffee', 'blackgram',
#        'pigeonpeas', 'rice', 'pigeonpeas', 'muskmelon', 'chickpea',
#        'rice', 'mungbean', 'rice', 'papaya', 'mungbean', 'chickpea',
#        'orange', 'cotton', 'mungbean', 'banana', 'cotton', 'maize',
#        'apple', 'coconut', 'banana', 'papaya', 'mungbean', 'chickpea',
#        'chickpea', 'rice', 'muskmelon', 'jute', 'rice', 'lentil',
#        'chickpea', 'papaya', 'rice', 'banana', 'banana', 'jute', 'apple',
#        'pomegranate', 'banana', 'maize', 'apple', 'pomegranate',
#        'mothbeans', 'pomegranate', 'mungbean', 'rice', 'maize', 'papaya',
#        'banana', 'blackgram', 'watermelon', 'jute', 'papaya', 'mango',
#        'coffee', 'kidneybeans', 'coconut', 'maize', 'chickpea', 'papaya',
#        'mungbean', 'papaya', 'apple', 'watermelon', 'cotton', 'jute',
#        'mungbean', 'mungbean', 'mango', 'coffee', 'maize', 'mothbeans',
#        'muskmelon', 'watermelon', 'coffee', 'blackgram', 'lentil',
#        'blackgram', 'pigeonpeas', 'rice', 'mango', 'watermelon', 'mango',
#        'apple', 'grapes', 'papaya', 'rice', 'coconut', 'jute', 'jute',
#        'lentil'], dtype=object)

# %%
import pickle

# %%
pickle.dump(model, open("model.pkl", "wb"))
